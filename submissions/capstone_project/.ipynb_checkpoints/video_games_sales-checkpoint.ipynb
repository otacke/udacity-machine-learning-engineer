# %% [markdown]
# # Predicting Video Game Sales
# First of all, we need to import some libraries.

# %%
# Import libraries necessary for this project
import numpy as np
import pandas as pd
#import visuals as vs
import matplotlib.pyplot as plt

# Allows the use of display() for DataFrames
from IPython.display import display

# make pretty
plt.style.use('ggplot')

# Pretty display for notebooks
# %matplotlib inline

# %% [markdown]
# # Data Schema
#
# ## Dataset 1 (Video_Games_Sales_as_at_22_Dec_2016.csv)
# This is my main dataset. It will be used to predict video game sales.
#
# | title           | description                                                   | data type |
# |-----------------|---------------------------------------------------------------|-----------|
# | Name            | Name of the game                                              | String    |
# | Platform        | Platform                                                      | String    |
# | Year_of_Release | Year of release                                               | Numeric   |
# | Genre           | Genre                                                         | String    |
# | Publisher       | Publisher                                                     | String    |
# | NA_Sales        | Game sales in North America (in millions of units)            | Numeric   |
# | EU_Sales        | Game sales in the European Union (in millions of units)       | Numeric   |
# | JP_Sales        | Game sales in Japan (in millions of units)                    | Numeric   |
# | Other_Sales     | Game sales in the rest of the world (in millions of units)    | Numeric   |
# | Global_Sales    | Total sales in the world (in millions of units)               | Numeric   |
# | Critic_Score    | Aggregate score compiled by Metacritic staff                  | Numeric   |
# | Critic_Count    | The number of critics used in coming up with the Critic_score | Numeric   |
# | User_Score      | Score by Metacritic's subscribers                             | Numeric   |
# | User_Count      | Number of users who gave the user_score                       | Numeric   |
# | Developer       | Party responsible for creating the game                       | String    |
# | Rating          | The [ESRB](https://www.esrb.org/) ratings                     | String    |
#
# ## Dataset 2 (ign.csv)
# This is my secondary dataset. It might be used to support the primary dataset, but this would probably require major effort for merging both.
#
# | title           | description                                                   | data type |
# |-----------------|---------------------------------------------------------------|-----------|
# | ID              | ID                                                            | Numeric   |
# | score_phrase    | Game rating as a phrase                                       | String    |
# | title           | Name of the game                                              | String    |
# | url             | URL to source of data                                         | String    |
# | platform        | Platform                                                      | String    |
# | score           | Game rating as a float                                        | Numeric   |
# | genre           | Genre                                                         | String    |
# | editors_choice  | Special recommendation of the editor                          | String    |
# | release_year    | Year of release                                               | Numeric   |
# | release_month   | Month of release                                              | Numeric   |
# | release_day     | Day of release                                                | Numeric   |

# %% [markdown]
# We can remove several colums in dataset2 that we don't need:
# * **ID** which is just an ID that's not used in dataset 1
# * **score_phrase**, because it redundant to _score_ and less precise
# * **url**, because that's just the origin of the data
# The next step will be to load the datasets.

# %%
# Load dataset #1
try:
    dataset1 = pd.read_csv("data/Video_Games_Sales_as_at_22_Dec_2016.csv")
    print "Dataset #1 has {} samples with {} features each.".format(*dataset1.shape)
except:
    print "Dataset #1 could not be loaded. Is the dataset missing?"

print('\n')
# Out:
# Dataset #1 has 16719 samples with 16 features each.

# %%
# Display a description of the datasets
display(dataset1.dtypes)
display(dataset1.head())
display(dataset1.tail())
display(dataset1.describe())
print('\n')
# Out:
# Name                object
# Platform            object
# Year_of_Release    float64
# Genre               object
# Publisher           object
# NA_Sales           float64
# EU_Sales           float64
# JP_Sales           float64
# Other_Sales        float64
# Global_Sales       float64
# Critic_Score       float64
# Critic_Count       float64
# User_Score          object
# User_Count         float64
# Developer           object
# Rating              object
# dtype: object
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii           2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES           1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii           2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii           2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 1     29.08      3.58      6.81         0.77         40.24           NaN
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 4     11.27      8.89     10.22         1.00         31.37           NaN
#
#    Critic_Count User_Score  User_Count Developer Rating
# 0          51.0          8       322.0  Nintendo      E
# 1           NaN        NaN         NaN       NaN    NaN
# 2          73.0        8.3       709.0  Nintendo      E
# 3          73.0          8       192.0  Nintendo      E
# 4           NaN        NaN         NaN       NaN    NaN
#                                 Name Platform  Year_of_Release       Genre  \
# 16714  Samurai Warriors: Sanada Maru      PS3           2016.0      Action
# 16715               LMA Manager 2007     X360           2006.0      Sports
# 16716        Haitaka no Psychedelica      PSV           2016.0   Adventure
# 16717               Spirits & Spells      GBA           2003.0    Platform
# 16718            Winning Post 8 2016      PSV           2016.0  Simulation
#
#           Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  \
# 16714    Tecmo Koei      0.00      0.00      0.01          0.0          0.01
# 16715   Codemasters      0.00      0.01      0.00          0.0          0.01
# 16716  Idea Factory      0.00      0.00      0.01          0.0          0.01
# 16717       Wanadoo      0.01      0.00      0.00          0.0          0.01
# 16718    Tecmo Koei      0.00      0.00      0.01          0.0          0.01
#
#        Critic_Score  Critic_Count User_Score  User_Count Developer Rating
# 16714           NaN           NaN        NaN         NaN       NaN    NaN
# 16715           NaN           NaN        NaN         NaN       NaN    NaN
# 16716           NaN           NaN        NaN         NaN       NaN    NaN
# 16717           NaN           NaN        NaN         NaN       NaN    NaN
# 16718           NaN           NaN        NaN         NaN       NaN    NaN
#        Year_of_Release      NA_Sales      EU_Sales      JP_Sales  \
# count     16450.000000  16719.000000  16719.000000  16719.000000
# mean       2006.487356      0.263330      0.145025      0.077602
# std           5.878995      0.813514      0.503283      0.308818
# min        1980.000000      0.000000      0.000000      0.000000
# 25%                NaN      0.000000      0.000000      0.000000
# 50%                NaN      0.080000      0.020000      0.000000
# 75%                NaN      0.240000      0.110000      0.040000
# max        2020.000000     41.360000     28.960000     10.220000
#
#         Other_Sales  Global_Sales  Critic_Score  Critic_Count    User_Count
# count  16719.000000  16719.000000   8137.000000   8137.000000   7590.000000
# mean       0.047332      0.533543     68.967679     26.360821    162.229908
# std        0.186710      1.547935     13.938165     18.980495    561.282326
# min        0.000000      0.010000     13.000000      3.000000      4.000000
# 25%        0.000000      0.060000           NaN           NaN           NaN
# 50%        0.010000      0.170000           NaN           NaN           NaN
# 75%        0.030000      0.470000           NaN           NaN           NaN
# max       10.570000     82.530000     98.000000    113.000000  10665.000000

# %% [markdown]
# * Clean up all strings
# * Remove rows without critic_score and user_score

# %%
# Sanitization

# beautify strings and kick 
for i in range(0, len(dataset1.axes[1])):
    if (dataset1.ix[:,i].dtype == object):
        dataset1.ix[:,i] = dataset1.ix[:,i].str.strip()

# tbd to NaN
dataset1 = dataset1.replace('tbd', float('NaN'))

# correct data types
dataset1['User_Score'].astype('float')

# Remove rows with empty values, we want full information
for column in dataset1.axes[1]:
    dataset1 = dataset1[dataset1[column].notnull()]

# dataset1 is now clean, make a copy for possibe use later
clean_dataset1 = dataset1.copy()

# display some infos
display(clean_dataset1.head())
print ('REMAINING ROWS IN DATASET #1: {}'.format(*clean_dataset1.shape))
print ('Dataset #1 has {} unique game name values'.format(clean_dataset1['Name'].unique().size))
print ('Dataset #1 has {} unique platforms values'.format(clean_dataset1['Platform'].unique().size))
print ('Dataset #1 has games from {} unique years'.format(clean_dataset1['Year_of_Release'].unique().size))
print ('Dataset #1 has {} unique genre values'.format(clean_dataset1['Genre'].unique().size))
print ('Dataset #1 has {} unique publisher values'.format(clean_dataset1['Publisher'].unique().size))
print ('Dataset #1 has {} unique developer values'.format(clean_dataset1['Developer'].unique().size))
print ('Dataset #1 has {} unique rating values'.format(clean_dataset1['Rating'].unique().size))
# Out:
#                     Name Platform  Year_of_Release     Genre Publisher  \
# 0             Wii Sports      Wii           2006.0    Sports  Nintendo
# 2         Mario Kart Wii      Wii           2008.0    Racing  Nintendo
# 3      Wii Sports Resort      Wii           2009.0    Sports  Nintendo
# 6  New Super Mario Bros.       DS           2006.0  Platform  Nintendo
# 7               Wii Play      Wii           2006.0      Misc  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 6     11.28      9.14      6.50         2.88         29.80          89.0
# 7     13.96      9.18      2.93         2.84         28.92          58.0
#
#    Critic_Count User_Score  User_Count Developer Rating
# 0          51.0          8       322.0  Nintendo      E
# 2          73.0        8.3       709.0  Nintendo      E
# 3          73.0          8       192.0  Nintendo      E
# 6          65.0        8.5       431.0  Nintendo      E
# 7          41.0        6.6       129.0  Nintendo      E
# REMAINING ROWS IN DATASET #1: 6825
# Dataset #1 has 4377 unique game name values
# Dataset #1 has 17 unique platforms values
# Dataset #1 has games from 25 unique years
# Dataset #1 has 12 unique genre values
# Dataset #1 has 261 unique publisher values
# Dataset #1 has 1289 unique developer values
# Dataset #1 has 7 unique rating values

# %%
# Feature Generation and further harmonizing data

# make a short dataset that will contain all rows considered for further analysis without outliers, etc.
short_dataset1 = clean_dataset1.copy()

# => too many unique values per feature for the dataset size, so features should be removed
short_dataset1 = short_dataset1.drop(['Name', 'Publisher', 'Developer'], axis=1)

# create Boolean columns for each remaining nominal variable
for platform in short_dataset1['Platform'].unique():
    short_dataset1['Platform_' + platform] = short_dataset1['Platform'].map(lambda x: True if x == platform else False)

for genre in short_dataset1['Genre'].unique():
    short_dataset1['Genre_' + genre] = short_dataset1['Genre'].map(lambda x: True if x == genre else False) 

for rating in short_dataset1['Rating'].unique():
    short_dataset1['Rating_' + rating] = short_dataset1['Rating'].map(lambda x: True if x == rating else False)

# Platform manufacturer based on the platform
man_microsoft = ['PC','X360','XB','XOne']
man_nintendo  = ['3DS','DS','GBA','GC','N64','Wii','WiiU']
man_sega      = ['DC']
man_sony      = ['PS','PS2','PS3','PS4' ,'PSP','PSV']

short_dataset1['Platform_Manufacturer'] = short_dataset1['Platform'].map(lambda x:
    'Microsoft' if x in man_microsoft else
    'Nintendo' if x in man_nintendo else
    'Sega' if x in man_sega else
    'Sony' if x in man_sony else
    float('NaN'))

# Portable based on the platform
portables = ['3DS','DS','GBA','PSP','PSV']

short_dataset1['Portable'] = short_dataset1['Platform'].map(lambda x: True if x in portables else False)

# remove old columns
short_dataset1 = short_dataset1.drop(['Platform', 'Genre', 'Rating'], axis=1)

# Scale User_Score to boundaries of Critic_Score
#short_dataset1[['User_Score']] = short_dataset1[['User_Score']] * 10

display(short_dataset1.head())
print ('REMAINING ROWS IN DATASET #1: {}'.format(*short_dataset1.shape))
print ('Dataset #1 has games from {} unique years'.format(short_dataset1['Year_of_Release'].unique().size))
# Out:
#    Year_of_Release  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  \
# 0           2006.0     41.36     28.96      3.77         8.45         82.53
# 2           2008.0     15.68     12.76      3.79         3.29         35.52
# 3           2009.0     15.61     10.93      3.28         2.95         32.77
# 6           2006.0     11.28      9.14      6.50         2.88         29.80
# 7           2006.0     13.96      9.18      2.93         2.84         28.92
#
#    Critic_Score  Critic_Count User_Score  User_Count   ...    Genre_Strategy  \
# 0          76.0          51.0          8       322.0   ...             False
# 2          82.0          73.0        8.3       709.0   ...             False
# 3          80.0          73.0          8       192.0   ...             False
# 6          89.0          65.0        8.5       431.0   ...             False
# 7          58.0          41.0        6.6       129.0   ...             False
#
#   Rating_E Rating_M Rating_T Rating_E10+ Rating_AO Rating_K-A Rating_RP  \
# 0     True    False    False       False     False      False     False
# 2     True    False    False       False     False      False     False
# 3     True    False    False       False     False      False     False
# 6     True    False    False       False     False      False     False
# 7     True    False    False       False     False      False     False
#
#   Platform_Manufacturer Portable
# 0              Nintendo    False
# 2              Nintendo    False
# 3              Nintendo    False
# 6              Nintendo     True
# 7              Nintendo    False
#
# [5 rows x 48 columns]
# REMAINING ROWS IN DATASET #1: 6825
# Dataset #1 has games from 25 unique years

# %%
# Outliers

# There are only few rows before 2000, because MetaCritic was founded in July 16, 1999
# I consider them to be outliers to be removed
short_dataset1 = short_dataset1[short_dataset1.Year_of_Release > 1999]

# display some infos
display(short_dataset1.head())
print ('REMAINING ROWS IN DATASET #1: {}'.format(*short_dataset1.shape))
print ('Dataset #1 has games from {} unique years'.format(short_dataset1['Year_of_Release'].unique().size))
# Out:
#    Year_of_Release  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  \
# 0           2006.0     41.36     28.96      3.77         8.45         82.53
# 2           2008.0     15.68     12.76      3.79         3.29         35.52
# 3           2009.0     15.61     10.93      3.28         2.95         32.77
# 6           2006.0     11.28      9.14      6.50         2.88         29.80
# 7           2006.0     13.96      9.18      2.93         2.84         28.92
#
#    Critic_Score  Critic_Count User_Score  User_Count   ...    Genre_Strategy  \
# 0          76.0          51.0          8       322.0   ...             False
# 2          82.0          73.0        8.3       709.0   ...             False
# 3          80.0          73.0          8       192.0   ...             False
# 6          89.0          65.0        8.5       431.0   ...             False
# 7          58.0          41.0        6.6       129.0   ...             False
#
#   Rating_E Rating_M Rating_T Rating_E10+ Rating_AO Rating_K-A Rating_RP  \
# 0     True    False    False       False     False      False     False
# 2     True    False    False       False     False      False     False
# 3     True    False    False       False     False      False     False
# 6     True    False    False       False     False      False     False
# 7     True    False    False       False     False      False     False
#
#   Platform_Manufacturer Portable
# 0              Nintendo    False
# 2              Nintendo    False
# 3              Nintendo    False
# 6              Nintendo     True
# 7              Nintendo    False
#
# [5 rows x 48 columns]
# REMAINING ROWS IN DATASET #1: 6746
# Dataset #1 has games from 17 unique years

# %%
# Show correlations between all variables
display(short_dataset1.corr()[short_dataset1.corr() > 0.7])
# display(short_dataset1.corr())
# Out:
#                     Year_of_Release  NA_Sales  EU_Sales  JP_Sales  \
# Year_of_Release                 1.0       NaN       NaN       NaN
# NA_Sales                        NaN  1.000000  0.841514       NaN
# EU_Sales                        NaN  0.841514  1.000000       NaN
# JP_Sales                        NaN       NaN       NaN       1.0
# Other_Sales                     NaN  0.728698  0.717841       NaN
# Global_Sales                    NaN  0.956288  0.939463       NaN
# Critic_Score                    NaN       NaN       NaN       NaN
# Critic_Count                    NaN       NaN       NaN       NaN
# User_Count                      NaN       NaN       NaN       NaN
# Platform_Wii                    NaN       NaN       NaN       NaN
# Platform_DS                     NaN       NaN       NaN       NaN
# Platform_X360                   NaN       NaN       NaN       NaN
# Platform_PS3                    NaN       NaN       NaN       NaN
# Platform_PS2                    NaN       NaN       NaN       NaN
# Platform_3DS                    NaN       NaN       NaN       NaN
# Platform_PS4                    NaN       NaN       NaN       NaN
# Platform_PS                     NaN       NaN       NaN       NaN
# Platform_XB                     NaN       NaN       NaN       NaN
# Platform_PC                     NaN       NaN       NaN       NaN
# Platform_PSP                    NaN       NaN       NaN       NaN
# Platform_WiiU                   NaN       NaN       NaN       NaN
# Platform_GC                     NaN       NaN       NaN       NaN
# Platform_GBA                    NaN       NaN       NaN       NaN
# Platform_XOne                   NaN       NaN       NaN       NaN
# Platform_PSV                    NaN       NaN       NaN       NaN
# Platform_DC                     NaN       NaN       NaN       NaN
# Genre_Sports                    NaN       NaN       NaN       NaN
# Genre_Racing                    NaN       NaN       NaN       NaN
# Genre_Platform                  NaN       NaN       NaN       NaN
# Genre_Misc                      NaN       NaN       NaN       NaN
# Genre_Action                    NaN       NaN       NaN       NaN
# Genre_Puzzle                    NaN       NaN       NaN       NaN
# Genre_Shooter                   NaN       NaN       NaN       NaN
# Genre_Fighting                  NaN       NaN       NaN       NaN
# Genre_Simulation                NaN       NaN       NaN       NaN
# Genre_Role-Playing              NaN       NaN       NaN       NaN
# Genre_Adventure                 NaN       NaN       NaN       NaN
# Genre_Strategy                  NaN       NaN       NaN       NaN
# Rating_E                        NaN       NaN       NaN       NaN
# Rating_M                        NaN       NaN       NaN       NaN
# Rating_T                        NaN       NaN       NaN       NaN
# Rating_E10+                     NaN       NaN       NaN       NaN
# Rating_AO                       NaN       NaN       NaN       NaN
# Rating_K-A                      NaN       NaN       NaN       NaN
# Rating_RP                       NaN       NaN       NaN       NaN
# Portable                        NaN       NaN       NaN       NaN
#
#                     Other_Sales  Global_Sales  Critic_Score  Critic_Count  \
# Year_of_Release             NaN           NaN           NaN           NaN
# NA_Sales               0.728698      0.956288           NaN           NaN
# EU_Sales               0.717841      0.939463           NaN           NaN
# JP_Sales                    NaN           NaN           NaN           NaN
# Other_Sales            1.000000      0.806961           NaN           NaN
# Global_Sales           0.806961      1.000000           NaN           NaN
# Critic_Score                NaN           NaN           1.0           NaN
# Critic_Count                NaN           NaN           NaN           1.0
# User_Count                  NaN           NaN           NaN           NaN
# Platform_Wii                NaN           NaN           NaN           NaN
# Platform_DS                 NaN           NaN           NaN           NaN
# Platform_X360               NaN           NaN           NaN           NaN
# Platform_PS3                NaN           NaN           NaN           NaN
# Platform_PS2                NaN           NaN           NaN           NaN
# Platform_3DS                NaN           NaN           NaN           NaN
# Platform_PS4                NaN           NaN           NaN           NaN
# Platform_PS                 NaN           NaN           NaN           NaN
# Platform_XB                 NaN           NaN           NaN           NaN
# Platform_PC                 NaN           NaN           NaN           NaN
# Platform_PSP                NaN           NaN           NaN           NaN
# Platform_WiiU               NaN           NaN           NaN           NaN
# Platform_GC                 NaN           NaN           NaN           NaN
# Platform_GBA                NaN           NaN           NaN           NaN
# Platform_XOne               NaN           NaN           NaN           NaN
# Platform_PSV                NaN           NaN           NaN           NaN
# Platform_DC                 NaN           NaN           NaN           NaN
# Genre_Sports                NaN           NaN           NaN           NaN
# Genre_Racing                NaN           NaN           NaN           NaN
# Genre_Platform              NaN           NaN           NaN           NaN
# Genre_Misc                  NaN           NaN           NaN           NaN
# Genre_Action                NaN           NaN           NaN           NaN
# Genre_Puzzle                NaN           NaN           NaN           NaN
# Genre_Shooter               NaN           NaN           NaN           NaN
# Genre_Fighting              NaN           NaN           NaN           NaN
# Genre_Simulation            NaN           NaN           NaN           NaN
# Genre_Role-Playing          NaN           NaN           NaN           NaN
# Genre_Adventure             NaN           NaN           NaN           NaN
# Genre_Strategy              NaN           NaN           NaN           NaN
# Rating_E                    NaN           NaN           NaN           NaN
# Rating_M                    NaN           NaN           NaN           NaN
# Rating_T                    NaN           NaN           NaN           NaN
# Rating_E10+                 NaN           NaN           NaN           NaN
# Rating_AO                   NaN           NaN           NaN           NaN
# Rating_K-A                  NaN           NaN           NaN           NaN
# Rating_RP                   NaN           NaN           NaN           NaN
# Portable                    NaN           NaN           NaN           NaN
#
#                     User_Count  Platform_Wii    ...     Genre_Adventure  \
# Year_of_Release            NaN           NaN    ...                 NaN
# NA_Sales                   NaN           NaN    ...                 NaN
# EU_Sales                   NaN           NaN    ...                 NaN
# JP_Sales                   NaN           NaN    ...                 NaN
# Other_Sales                NaN           NaN    ...                 NaN
# Global_Sales               NaN           NaN    ...                 NaN
# Critic_Score               NaN           NaN    ...                 NaN
# Critic_Count               NaN           NaN    ...                 NaN
# User_Count                 1.0           NaN    ...                 NaN
# Platform_Wii               NaN           1.0    ...                 NaN
# Platform_DS                NaN           NaN    ...                 NaN
# Platform_X360              NaN           NaN    ...                 NaN
# Platform_PS3               NaN           NaN    ...                 NaN
# Platform_PS2               NaN           NaN    ...                 NaN
# Platform_3DS               NaN           NaN    ...                 NaN
# Platform_PS4               NaN           NaN    ...                 NaN
# Platform_PS                NaN           NaN    ...                 NaN
# Platform_XB                NaN           NaN    ...                 NaN
# Platform_PC                NaN           NaN    ...                 NaN
# Platform_PSP               NaN           NaN    ...                 NaN
# Platform_WiiU              NaN           NaN    ...                 NaN
# Platform_GC                NaN           NaN    ...                 NaN
# Platform_GBA               NaN           NaN    ...                 NaN
# Platform_XOne              NaN           NaN    ...                 NaN
# Platform_PSV               NaN           NaN    ...                 NaN
# Platform_DC                NaN           NaN    ...                 NaN
# Genre_Sports               NaN           NaN    ...                 NaN
# Genre_Racing               NaN           NaN    ...                 NaN
# Genre_Platform             NaN           NaN    ...                 NaN
# Genre_Misc                 NaN           NaN    ...                 NaN
# Genre_Action               NaN           NaN    ...                 NaN
# Genre_Puzzle               NaN           NaN    ...                 NaN
# Genre_Shooter              NaN           NaN    ...                 NaN
# Genre_Fighting             NaN           NaN    ...                 NaN
# Genre_Simulation           NaN           NaN    ...                 NaN
# Genre_Role-Playing         NaN           NaN    ...                 NaN
# Genre_Adventure            NaN           NaN    ...                 1.0
# Genre_Strategy             NaN           NaN    ...                 NaN
# Rating_E                   NaN           NaN    ...                 NaN
# Rating_M                   NaN           NaN    ...                 NaN
# Rating_T                   NaN           NaN    ...                 NaN
# Rating_E10+                NaN           NaN    ...                 NaN
# Rating_AO                  NaN           NaN    ...                 NaN
# Rating_K-A                 NaN           NaN    ...                 NaN
# Rating_RP                  NaN           NaN    ...                 NaN
# Portable                   NaN           NaN    ...                 NaN
#
#                     Genre_Strategy  Rating_E  Rating_M  Rating_T  Rating_E10+  \
# Year_of_Release                NaN       NaN       NaN       NaN          NaN
# NA_Sales                       NaN       NaN       NaN       NaN          NaN
# EU_Sales                       NaN       NaN       NaN       NaN          NaN
# JP_Sales                       NaN       NaN       NaN       NaN          NaN
# Other_Sales                    NaN       NaN       NaN       NaN          NaN
# Global_Sales                   NaN       NaN       NaN       NaN          NaN
# Critic_Score                   NaN       NaN       NaN       NaN          NaN
# Critic_Count                   NaN       NaN       NaN       NaN          NaN
# User_Count                     NaN       NaN       NaN       NaN          NaN
# Platform_Wii                   NaN       NaN       NaN       NaN          NaN
# Platform_DS                    NaN       NaN       NaN       NaN          NaN
# Platform_X360                  NaN       NaN       NaN       NaN          NaN
# Platform_PS3                   NaN       NaN       NaN       NaN          NaN
# Platform_PS2                   NaN       NaN       NaN       NaN          NaN
# Platform_3DS                   NaN       NaN       NaN       NaN          NaN
# Platform_PS4                   NaN       NaN       NaN       NaN          NaN
# Platform_PS                    NaN       NaN       NaN       NaN          NaN
# Platform_XB                    NaN       NaN       NaN       NaN          NaN
# Platform_PC                    NaN       NaN       NaN       NaN          NaN
# Platform_PSP                   NaN       NaN       NaN       NaN          NaN
# Platform_WiiU                  NaN       NaN       NaN       NaN          NaN
# Platform_GC                    NaN       NaN       NaN       NaN          NaN
# Platform_GBA                   NaN       NaN       NaN       NaN          NaN
# Platform_XOne                  NaN       NaN       NaN       NaN          NaN
# Platform_PSV                   NaN       NaN       NaN       NaN          NaN
# Platform_DC                    NaN       NaN       NaN       NaN          NaN
# Genre_Sports                   NaN       NaN       NaN       NaN          NaN
# Genre_Racing                   NaN       NaN       NaN       NaN          NaN
# Genre_Platform                 NaN       NaN       NaN       NaN          NaN
# Genre_Misc                     NaN       NaN       NaN       NaN          NaN
# Genre_Action                   NaN       NaN       NaN       NaN          NaN
# Genre_Puzzle                   NaN       NaN       NaN       NaN          NaN
# Genre_Shooter                  NaN       NaN       NaN       NaN          NaN
# Genre_Fighting                 NaN       NaN       NaN       NaN          NaN
# Genre_Simulation               NaN       NaN       NaN       NaN          NaN
# Genre_Role-Playing             NaN       NaN       NaN       NaN          NaN
# Genre_Adventure                NaN       NaN       NaN       NaN          NaN
# Genre_Strategy                 1.0       NaN       NaN       NaN          NaN
# Rating_E                       NaN       1.0       NaN       NaN          NaN
# Rating_M                       NaN       NaN       1.0       NaN          NaN
# Rating_T                       NaN       NaN       NaN       1.0          NaN
# Rating_E10+                    NaN       NaN       NaN       NaN          1.0
# Rating_AO                      NaN       NaN       NaN       NaN          NaN
# Rating_K-A                     NaN       NaN       NaN       NaN          NaN
# Rating_RP                      NaN       NaN       NaN       NaN          NaN
# Portable                       NaN       NaN       NaN       NaN          NaN
#
#                     Rating_AO  Rating_K-A  Rating_RP  Portable
# Year_of_Release           NaN         NaN        NaN       NaN
# NA_Sales                  NaN         NaN        NaN       NaN
# EU_Sales                  NaN         NaN        NaN       NaN
# JP_Sales                  NaN         NaN        NaN       NaN
# Other_Sales               NaN         NaN        NaN       NaN
# Global_Sales              NaN         NaN        NaN       NaN
# Critic_Score              NaN         NaN        NaN       NaN
# Critic_Count              NaN         NaN        NaN       NaN
# User_Count                NaN         NaN        NaN       NaN
# Platform_Wii              NaN         NaN        NaN       NaN
# Platform_DS               NaN         NaN        NaN       NaN
# Platform_X360             NaN         NaN        NaN       NaN
# Platform_PS3              NaN         NaN        NaN       NaN
# Platform_PS2              NaN         NaN        NaN       NaN
# Platform_3DS              NaN         NaN        NaN       NaN
# Platform_PS4              NaN         NaN        NaN       NaN
# Platform_PS               NaN         NaN        NaN       NaN
# Platform_XB               NaN         NaN        NaN       NaN
# Platform_PC               NaN         NaN        NaN       NaN
# Platform_PSP              NaN         NaN        NaN       NaN
# Platform_WiiU             NaN         NaN        NaN       NaN
# Platform_GC               NaN         NaN        NaN       NaN
# Platform_GBA              NaN         NaN        NaN       NaN
# Platform_XOne             NaN         NaN        NaN       NaN
# Platform_PSV              NaN         NaN        NaN       NaN
# Platform_DC               NaN         NaN        NaN       NaN
# Genre_Sports              NaN         NaN        NaN       NaN
# Genre_Racing              NaN         NaN        NaN       NaN
# Genre_Platform            NaN         NaN        NaN       NaN
# Genre_Misc                NaN         NaN        NaN       NaN
# Genre_Action              NaN         NaN        NaN       NaN
# Genre_Puzzle              NaN         NaN        NaN       NaN
# Genre_Shooter             NaN         NaN        NaN       NaN
# Genre_Fighting            NaN         NaN        NaN       NaN
# Genre_Simulation          NaN         NaN        NaN       NaN
# Genre_Role-Playing        NaN         NaN        NaN       NaN
# Genre_Adventure           NaN         NaN        NaN       NaN
# Genre_Strategy            NaN         NaN        NaN       NaN
# Rating_E                  NaN         NaN        NaN       NaN
# Rating_M                  NaN         NaN        NaN       NaN
# Rating_T                  NaN         NaN        NaN       NaN
# Rating_E10+               NaN         NaN        NaN       NaN
# Rating_AO                 1.0         NaN        NaN       NaN
# Rating_K-A                NaN         NaN        NaN       NaN
# Rating_RP                 NaN         NaN        1.0       NaN
# Portable                  NaN         NaN        NaN       1.0
#
# [46 rows x 46 columns]

# %% [markdown]
# In order to understand the dataset better, we should have a look at possible values.

# %%
# stats
print('MEDIAN')
display(short_dataset1.median())
print('STANDARD DEVIATION')
display(short_dataset1.std())

# TODO: Check for outliers, see below visually
# Out:
# MEDIAN
# Year_of_Release       2007.00
# NA_Sales                 0.15
# EU_Sales                 0.06
# JP_Sales                 0.00
# Other_Sales              0.02
# Global_Sales             0.29
# Critic_Score            72.00
# Critic_Count            25.00
# User_Count              27.00
# Platform_Wii             0.00
# Platform_DS              0.00
# Platform_X360            0.00
# Platform_PS3             0.00
# Platform_PS2             0.00
# Platform_3DS             0.00
# Platform_PS4             0.00
# Platform_PS              0.00
# Platform_XB              0.00
# Platform_PC              0.00
# Platform_PSP             0.00
# Platform_WiiU            0.00
# Platform_GC              0.00
# Platform_GBA             0.00
# Platform_XOne            0.00
# Platform_PSV             0.00
# Platform_DC              0.00
# Genre_Sports             0.00
# Genre_Racing             0.00
# Genre_Platform           0.00
# Genre_Misc               0.00
# Genre_Action             0.00
# Genre_Puzzle             0.00
# Genre_Shooter            0.00
# Genre_Fighting           0.00
# Genre_Simulation         0.00
# Genre_Role-Playing       0.00
# Genre_Adventure          0.00
# Genre_Strategy           0.00
# Rating_E                 0.00
# Rating_M                 0.00
# Rating_T                 0.00
# Rating_E10+              0.00
# Rating_AO                0.00
# Rating_K-A               0.00
# Rating_RP                0.00
# Portable                 0.00
# dtype: float64
# STANDARD DEVIATION
# Year_of_Release         4.091946
# NA_Sales                0.963955
# EU_Sales                0.684310
# JP_Sales                0.275664
# Other_Sales             0.270845
# Global_Sales            1.951595
# Critic_Score           13.829731
# Critic_Count           19.242673
# User_Count            584.894703
# Platform_Wii            0.256852
# Platform_DS             0.253101
# Platform_X360           0.333206
# Platform_PS3            0.317827
# Platform_PS2            0.374770
# Platform_3DS            0.149840
# Platform_PS4            0.184874
# Platform_PS             0.111549
# Platform_XB             0.277038
# Platform_PC             0.293058
# Platform_PSP            0.233405
# Platform_WiiU           0.114109
# Platform_GC             0.221206
# Platform_GBA            0.184127
# Platform_XOne           0.151715
# Platform_PSV            0.131105
# Platform_DC             0.040351
# Genre_Sports            0.346483
# Genre_Racing            0.279253
# Genre_Platform          0.235361
# Genre_Misc              0.231144
# Genre_Action            0.427111
# Genre_Puzzle            0.130008
# Genre_Shooter           0.333372
# Genre_Fighting          0.227409
# Genre_Simulation        0.203180
# Genre_Role-Playing      0.303237
# Genre_Adventure         0.187094
# Genre_Strategy          0.192868
# Rating_E                0.460471
# Rating_M                0.407691
# Rating_T                0.475867
# Rating_E10+             0.344622
# Rating_AO               0.012175
# Rating_K-A              0.000000
# Rating_RP               0.012175
# Portable                0.401666
# dtype: float64

# %%
## TESTING: FEATURE SCALING
# If data is not normally distributed, especially if the mean and median vary significantly (indicating a large skew), it is most often appropriate to apply a non-linear scaling

# Produce a scatter matrix for each pair of features in the data
# pd.scatter_matrix(short_dataset1, alpha = 0.3, figsize = (14,8), diagonal = 'kde');

# TODO: Scale the data using the natural logarithm
df2 = short_dataset1[['Year_of_Release', 'Global_Sales', 'Critic_Score', 'User_Score']].copy()

#log_data = np.log(df2)
log_data = df2.copy()
#pd.scatter_matrix(log_data, alpha = 0.3, figsize = (14,8), diagonal = 'kde');

# GOOD RESULTS! BUT TRY A BOX-COX-TEST!!! http://scipy.github.io/devdocs/generated/scipy.stats.boxcox.html
# Out:
#        Year_of_Release  Global_Sales  Critic_Score User_Score
# 0               2006.0         82.53          76.0          8
# 2               2008.0         35.52          82.0        8.3
# 3               2009.0         32.77          80.0          8
# 6               2006.0         29.80          89.0        8.5
# 7               2006.0         28.92          58.0        6.6
# 8               2009.0         28.32          87.0        8.4
# 11              2005.0         23.21          91.0        8.6
# 13              2007.0         22.70          80.0        7.7
# 14              2010.0         21.81          61.0        6.3
# 15              2009.0         21.79          80.0        7.4
# 16              2013.0         21.04          97.0        8.2
# 17              2004.0         20.81          95.0          9
# 19              2005.0         20.15          77.0        7.9
# 23              2013.0         16.27          97.0        8.1
# 24              2002.0         16.15          95.0        8.7
# 26              2005.0         15.29          77.0        7.1
# 28              2001.0         14.98          95.0        8.4
# 29              2011.0         14.73          88.0        3.4
# 32              2010.0         14.61          87.0        6.3
# 34              2012.0         13.79          83.0        5.3
# 35              2012.0         13.67          83.0        4.8
# 36              2009.0         13.47          94.0        6.3
# 37              2011.0         13.32          88.0        3.2
# 38              2001.0         13.10          97.0        8.5
# 39              2008.0         12.84          93.0        8.9
# 40              2011.0         12.66          85.0        8.2
# 41              2010.0         12.63          88.0        6.4
# 42              2014.0         12.61          97.0        8.3
# 43              2005.0         12.13          86.0        8.7
# 44              2007.0         12.12          94.0        7.8
# ...                ...           ...           ...        ...
# 16513           2016.0          0.01          78.0        7.9
# 16514           2015.0          0.01          82.0        8.3
# 16527           2002.0          0.01          83.0        8.3
# 16530           2016.0          0.01          61.0        7.9
# 16532           2009.0          0.01          78.0        6.9
# 16533           2007.0          0.01          55.0        7.9
# 16534           2016.0          0.01          51.0        5.5
# 16536           2008.0          0.01          55.0        5.7
# 16541           2007.0          0.01          63.0        7.5
# 16549           2008.0          0.01          58.0          8
# 16550           2004.0          0.01          78.0        9.5
# 16553           2007.0          0.01          74.0        7.6
# 16569           2002.0          0.01          64.0          8
# 16573           2010.0          0.01          69.0        7.9
# 16576           2009.0          0.01          82.0        8.6
# 16588           2012.0          0.01          78.0        7.9
# 16595           2006.0          0.01          64.0        6.8
# 16601           2015.0          0.01          65.0          6
# 16617           2012.0          0.01          49.0        2.1
# 16618           2003.0          0.01          70.0        8.7
# 16624           2009.0          0.01          80.0        8.2
# 16631           2003.0          0.01          81.0        9.5
# 16634           2016.0          0.01          63.0        8.2
# 16644           2007.0          0.01          51.0        3.8
# 16656           2016.0          0.01          81.0        8.5
# 16667           2001.0          0.01          46.0        2.4
# 16677           2002.0          0.01          81.0        8.8
# 16696           2014.0          0.01          80.0        7.6
# 16700           2011.0          0.01          61.0        5.8
# 16706           2011.0          0.01          60.0        7.2
#
# [6746 rows x 4 columns]

# %%
## TESTING: OUTLIER DETECTION

# For each feature find the data points with extreme high or low values
outliers = []
for feature in log_data.keys():

    # TODO: Calculate Q1 (25th percentile of the data) for the given feature
    Q1 = log_data[feature].quantile(0.25)

    # TODO: Calculate Q3 (75th percentile of the data) for the given feature
    Q3 = log_data[feature].quantile(0.75)
    
    # TODO: Use the interquartile range to calculate an outlier step (1.5 times the interquartile range)
    step = (Q3 - Q1) * 1.5
    
    # Display the outliers
    print "Data points considered outliers for the feature '{}':".format(feature)
    display(log_data[~((log_data[feature] >= Q1 - step) & (log_data[feature] <= Q3 + step))])
    outliers.extend(log_data[~((log_data[feature] >= Q1 - step) & (log_data[feature] <= Q3 + step))].index.values)
    
    # remove outliers
    # log_data = log_data[((log_data[feature] >= Q1 - step) & (log_data[feature] <= Q3 + step))]
    
# OPTIONAL: Select the indices for data points you wish to remove

df2.ix[outliers]

# Remove the outliers, if any were specified
#good_data = log_data.drop(log_data.index[outliers]).reset_index(drop = True)
# Out:
# Data points considered outliers for the feature 'Year_of_Release':
# Empty DataFrame
# Columns: [Year_of_Release, Global_Sales, Critic_Score, User_Score]
# Index: []
# Data points considered outliers for the feature 'Global_Sales':
#       Year_of_Release  Global_Sales  Critic_Score User_Score
# 0              2006.0         82.53          76.0          8
# 2              2008.0         35.52          82.0        8.3
# 3              2009.0         32.77          80.0          8
# 6              2006.0         29.80          89.0        8.5
# 7              2006.0         28.92          58.0        6.6
# 8              2009.0         28.32          87.0        8.4
# 11             2005.0         23.21          91.0        8.6
# 13             2007.0         22.70          80.0        7.7
# 14             2010.0         21.81          61.0        6.3
# 15             2009.0         21.79          80.0        7.4
# 16             2013.0         21.04          97.0        8.2
# 17             2004.0         20.81          95.0          9
# 19             2005.0         20.15          77.0        7.9
# 23             2013.0         16.27          97.0        8.1
# 24             2002.0         16.15          95.0        8.7
# 26             2005.0         15.29          77.0        7.1
# 28             2001.0         14.98          95.0        8.4
# 29             2011.0         14.73          88.0        3.4
# 32             2010.0         14.61          87.0        6.3
# 34             2012.0         13.79          83.0        5.3
# 35             2012.0         13.67          83.0        4.8
# 36             2009.0         13.47          94.0        6.3
# 37             2011.0         13.32          88.0        3.2
# 38             2001.0         13.10          97.0        8.5
# 39             2008.0         12.84          93.0        8.9
# 40             2011.0         12.66          85.0        8.2
# 41             2010.0         12.63          88.0        6.4
# 42             2014.0         12.61          97.0        8.3
# 43             2005.0         12.13          86.0        8.7
# 44             2007.0         12.12          94.0        7.8
# ...               ...           ...           ...        ...
# 1015           2013.0          1.75          65.0        6.8
# 1016           2008.0          1.75          55.0        6.2
# 1020           2002.0          1.74          83.0        8.7
# 1022           2012.0          1.74          55.0        3.5
# 1023           2012.0          1.74          78.0        8.3
# 1026           2015.0          1.74          63.0        6.6
# 1027           2001.0          1.73          92.0        8.9
# 1028           2013.0          1.73          54.0        6.5
# 1031           2010.0          1.73          78.0        8.1
# 1032           2002.0          1.73          78.0        7.9
# 1033           2012.0          1.73          79.0        7.1
# 1035           2014.0          1.72          61.0        5.4
# 1037           2014.0          1.72          82.0        6.3
# 1038           2004.0          1.72          91.0        7.6
# 1039           2003.0          1.72          80.0        7.7
# 1040           2011.0          1.72          78.0        2.5
# 1041           2012.0          1.71          88.0        7.9
# 1043           2009.0          1.71          89.0        8.9
# 1044           2004.0          1.71          84.0        9.1
# 1045           2003.0          1.71          83.0        8.7
# 1050           2007.0          1.70          20.0        1.9
# 1052           2011.0          1.70          95.0        8.4
# 1054           2006.0          1.70          87.0        8.6
# 1055           2010.0          1.70          74.0        5.3
# 1056           2016.0          1.70          71.0        4.5
# 1059           2005.0          1.69          82.0        8.8
# 1060           2013.0          1.69          94.0        8.5
# 1065           2001.0          1.69          64.0        7.1
# 1066           2002.0          1.69          53.0        6.9
# 1068           2005.0          1.69          96.0        9.4
#
# [670 rows x 4 columns]
# Data points considered outliers for the feature 'Critic_Score':
#        Year_of_Release  Global_Sales  Critic_Score User_Score
# 622             2007.0          2.48          25.0        4.3
# 916             2008.0          1.88          29.0        4.6
# 1050            2007.0          1.70          20.0        1.9
# 1294            2012.0          1.47          33.0        4.8
# 1562            2008.0          1.27          30.0          2
# 1614            2001.0          1.23          32.0        4.6
# 2588            2001.0          0.79          34.0        5.3
# 3197            2013.0          0.63          32.0          4
# 3342            2010.0          0.60          32.0        4.6
# 3437            2010.0          0.58          33.0        3.7
# 3899            2013.0          0.51          34.0        3.6
# 4967            2013.0          0.38          33.0        6.2
# 5241            2012.0          0.36          31.0        2.7
# 5313            2007.0          0.35          27.0        4.8
# 5539            2010.0          0.33          26.0        3.7
# 5735            2014.0          0.31          32.0        3.6
# 5747            2001.0          0.31          26.0        3.8
# 5811            2002.0          0.31          32.0        2.4
# 5825            2002.0          0.30          27.0        8.9
# 6039            2002.0          0.29          30.0        5.1
# 6634            2001.0          0.25          30.0        6.3
# 7012            2007.0          0.23          27.0        5.1
# 7219            2002.0          0.22          19.0        4.3
# 7346            2009.0          0.21          25.0        3.8
# 7374            2000.0          0.21          26.0          4
# 7457            2000.0          0.21          28.0        2.4
# 7480            2015.0          0.21          32.0        1.5
# 7486            2002.0          0.21          33.0        7.5
# 7513            2006.0          0.20          33.0        5.1
# 7791            2013.0          0.19          23.0          3
# ...                ...           ...           ...        ...
# 12179           2002.0          0.07          24.0        3.7
# 12289           2001.0          0.06          32.0        2.5
# 12387           2005.0          0.06          32.0        5.8
# 12646           2008.0          0.06          29.0        3.3
# 12669           2008.0          0.06          30.0        3.5
# 12757           2015.0          0.06          25.0        1.9
# 12765           2011.0          0.06          33.0        5.6
# 12823           2013.0          0.06          19.0        1.3
# 12868           2007.0          0.05          30.0        3.6
# 13072           2010.0          0.05          33.0        6.6
# 13118           2007.0          0.05          26.0        2.8
# 13284           2005.0          0.05          30.0        3.4
# 13427           2007.0          0.05          32.0        0.7
# 13445           2006.0          0.05          34.0        1.7
# 13690           2013.0          0.04          13.0          1
# 13823           2002.0          0.04          31.0          5
# 13888           2006.0          0.04          34.0        2.2
# 14230           2007.0          0.03          32.0          4
# 14401           2008.0          0.03          31.0        5.4
# 14897           2007.0          0.03          33.0        2.5
# 15022           2003.0          0.02          26.0        3.7
# 15073           2006.0          0.02          30.0        4.2
# 15345           2007.0          0.02          19.0        2.8
# 15453           2005.0          0.02          33.0        2.8
# 15523           2014.0          0.02          26.0        2.4
# 15611           2003.0          0.02          23.0        3.3
# 15737           2003.0          0.02          30.0        3.6
# 15770           2003.0          0.02          24.0        2.8
# 15949           2005.0          0.02          33.0          7
# 16356           2003.0          0.01          27.0        3.1
#
# [105 rows x 4 columns]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-34-81ccb35ca2c6> in <module>()
#       6
#       7     # TODO: Calculate Q1 (25th percentile of the data) for the given feature
# ----> 8     Q1 = log_data[feature].quantile(0.25)
#       9
#      10     # TODO: Calculate Q3 (75th percentile of the data) for the given feature
#
# C:\Users\tackeo\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas\core\series.pyc in quantile(self, q, interpolation)
#    1359             kwargs.update({'interpolation': interpolation})
#    1360
# -> 1361         result = self._data.quantile(qs=q, **kwargs)
#    1362
#    1363         if com.is_list_like(result):
#
# C:\Users\tackeo\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas\core\internals.pyc in quantile(self, **kwargs)
#    2912
#    2913     def quantile(self, **kwargs):
# -> 2914         return self.apply('quantile', raw=True, **kwargs)
#    2915
#    2916     def setitem(self, **kwargs):
#
# C:\Users\tackeo\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas\core\internals.pyc in apply(self, f, axes, filter, do_integrity_check, consolidate, raw, **kwargs)
#    2888
#    2889             kwargs['mgr'] = self
# -> 2890             applied = getattr(b, f)(**kwargs)
#    2891             result_blocks = _extend_blocks(applied, result_blocks)
#    2892
#
# C:\Users\tackeo\AppData\Local\Continuum\Anaconda2\lib\site-packages\pandas\core\internals.pyc in quantile(self, qs, mgr, **kwargs)
#    1284             result = np.array(values)
#    1285         else:
# -> 1286             result = _quantile(values, qs * 100, **kwargs)
#    1287
#    1288         return self._try_coerce_result(result)
#
# C:\Users\tackeo\AppData\Local\Continuum\Anaconda2\lib\site-packages\numpy\lib\function_base.pyc in percentile(a, q, axis, out, overwrite_input, interpolation, keepdims)
#    3697     r, k = _ureduce(a, func=_percentile, q=q, axis=axis, out=out,
#    3698                     overwrite_input=overwrite_input,
# -> 3699                     interpolation=interpolation)
#    3700     if keepdims:
#    3701         if q.ndim == 0:
#
# C:\Users\tackeo\AppData\Local\Continuum\Anaconda2\lib\site-packages\numpy\lib\function_base.pyc in _ureduce(a, func, **kwargs)
#    3423         keepdim = [1] * a.ndim
#    3424
# -> 3425     r = func(a, **kwargs)
#    3426     return r, keepdim
#    3427
#
# C:\Users\tackeo\AppData\Local\Continuum\Anaconda2\lib\site-packages\numpy\lib\function_base.pyc in _percentile(a, q, axis, out, overwrite_input, interpolation, keepdims)
#    3814             n = np.isnan(ap[-1:, ...])
#    3815
# -> 3816         x1 = take(ap, indices_below, axis=axis) * weights_below
#    3817         x2 = take(ap, indices_above, axis=axis) * weights_above
#    3818
#
# TypeError: can't multiply sequence by non-int of type 'float'

# %%
## TESTING PCA

from sklearn.decomposition import PCA

# TODO: Apply PCA by fitting the good data with the same number of dimensions as features
#pca = PCA(n_components=6)
#pca.fit(good_data)

# TODO: Transform the sample log-data using the PCA fit above
#pca_samples = pca.transform(log_samples)

# Generate PCA results plot
#pca_results = vs.pca_results(good_data, pca)

# Display sample log-data after having a PCA transformation applied
#display(pd.DataFrame(np.round(pca_samples, 4), columns = pca_results.index.values))

# TODO: Apply PCA by fitting the good data with only two dimensions
#pca = PCA(n_components = 2)
#pca.fit(good_data)

# TODO: Transform the good data using the PCA fit above
#reduced_data = pca.transform(good_data)

# TODO: Transform the sample log-data using the PCA fit above
#pca_samples = pca.transform(log_samples)

# Create a DataFrame for the reduced data
#reduced_data = pd.DataFrame(reduced_data, columns = ['Dimension 1', 'Dimension 2'])

# Display sample log-data after applying PCA transformation in two dimensions
#display(pd.DataFrame(np.round(pca_samples, 4), columns = ['Dimension 1', 'Dimension 2']))

# %% [markdown]
# Also, Plots will probably help ...

# %%
# Are there high correlations?
df1.corr()
# df1.corr()[df1.corr() > 0.7]

# NA_Sales with EU_Sales and yet Other_Sales => Global_Sales
# Critic_Score and User_Score only 0.580318, had not expected that

# TODO: data.drop(...)

# No other correlations, also not for booleans

# %%
# Critic_Score and User_Score
df1.plot.scatter(x='Critic_Score', y='User_Score')

# %%
# NA_Sales and Global_Sales
df1.plot.scatter(x='NA_Sales', y='Global_Sales')

# %%
# Just for testing
groups = df1.groupby('Platform_Manufacturer')

# Plot
fig, ax = plt.subplots()
for name, group in groups:
    ax.plot(group.Critic_Score, group.User_Score, marker='.', linestyle='', label=name)
ax.legend()

plt.show()

# Just for testing
groups = df1.groupby('Platform_Manufacturer')

# Plot
fig, ax = plt.subplots()
for name, group in groups:
    ax.plot(group.Critic_Score, group.Global_Sales, marker='.', linestyle='', label=name)
ax.legend()

plt.show()

# Just for testing
groups = df1.groupby('Platform_Manufacturer')

# Plot
fig, ax = plt.subplots()
for name, group in groups:
    ax.plot(group.User_Score, group.Global_Sales, marker='.', linestyle='', label=name)
ax.legend()

plt.show()

# Just for testing
groups = df1.groupby('Portable')

# Plot
fig, ax = plt.subplots()
for name, group in groups:
    ax.plot(group.Critic_Score, group.Global_Sales, marker='.', linestyle='', label=name)
ax.legend()

plt.show()

# Just for testing
groups = df1.groupby('Portable')

# Plot
fig, ax = plt.subplots()
for name, group in groups:
    ax.plot(group.User_Score, group.Global_Sales, marker='.', linestyle='', label=name)
ax.legend()

plt.show()

# %%
# Global_Sales
df1.boxplot(['Global_Sales'], by=['Platform_Manufacturer'])

# %%
# Don't forget ...
# vs.ModelLearning(...) from external file
# vs.ModelComplexity(...) from external file in customer_segments
